# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
# Load the .csv files into a Pandas dataframe 

cities = pd.read_csv('cities.csv', encoding='ISO-8859-1')
customers = pd.read_csv('customers.csv', encoding='ISO-8859-1')
item_master = pd.read_csv('item_master.csv', encoding='ISO-8859-1')
sales_rep = pd.read_csv('sales_rep.csv', encoding='ISO-8859-1')
sales = pd.read_csv('sales.csv', encoding='ISO-8859-1')

# %%
# Check if there are any duplicate rows in the 'cities' dataframe
# and return True if duplicates exist, False otherwise

cities.duplicated().any()
# Out:
# False

# %%
# Check if there are any duplicate rows in the 'customers' dataframe
# and return True if duplicates exist, False otherwise

customers.duplicated().any()
# Out:
# False

# %%
# Check if there are any duplicate rows in the 'item_master' dataframe
# and return True if duplicates exist, False otherwise

item_master.duplicated().any()
# Out:
# False

# %%
# Check if there are any duplicate rows in the 'sales_rep' dataframe
# and return True if duplicates exist, False otherwise

sales_rep.duplicated().any()
# Out:
# False

# %%
# Check if there are any duplicate rows in the 'sales' dataframe
# and return True if duplicates exist, False otherwise

sales.duplicated().any()
# Out:
# False

# %%
# Check if there are any missing (NaN) values in the 'cities' dataframe
# and return True if any are found, False otherwise

cities.isnull().any()
# Out:
# City         False
# City Code    False
# Region       False
# Latitude     False
# Longitude    False
# Desc          True
# dtype: bool

# %%
# Check if there are any missing (NaN) values in the 'customers' dataframe
# and return True if any are found, False otherwise

customers.isnull().any()
# Out:
# Customer           False
# Customer Number    False
# City Code          False
# dtype: bool

# %%
# Check if there are any missing (NaN) values in the 'item_master' dataframe
# and return True if any are found, False otherwise

item_master.isnull().any()
# Out:
# Item Number          False
# Product Group        False
# Product Line         False
# Product Sub Group    False
# Product Type         False
# dtype: bool

# %%
# Check if there are any missing (NaN) values in the 'sales_rep' dataframe
# and return True if any are found, False otherwise

sales_rep.isnull().any()
# Out:
# Manager            False
# Manager Number     False
# Path               False
# Sales Rep Name     False
# Sales Rep Name1    False
# Sales Rep Name2     True
# Sales Rep Name3     True
# Sales Rep ID       False
# dtype: bool

# %%
# Check if there are any missing (NaN) values in the 'sales' dataframe
# and return True if any are found, False otherwise

sales.isnull().any()
# Out:
# %KEY                      False
# Cost                      False
# Customer Number           False
# Date                      False
# GrossSales                False
# Invoice Date              False
# Invoice Number            False
# Item Desc                 False
# Item Number               False
# Margin                    False
# Order Number              False
# Promised Delivery Date    False
# Sales                     False
# Sales Qty                 False
# Sales Rep Number          False
# dtype: bool

# %%
# Print a summary of the 'cities' dataframe
cities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   City       100 non-null    object
#  1   City Code  100 non-null    int64
#  2   Region     100 non-null    object
#  3   Latitude   100 non-null    float64
#  4   Longitude  100 non-null    float64
#  5   Desc       99 non-null     object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 4.8+ KB

# %%
# Select rows from the 'cities' dataframe where the 'Desc' column is missing (NaN)

cities.loc[cities['Desc'].isnull()]
# Out:
#         City  City Code Region   Latitude   Longitude Desc
# 94  Yokohama         95  Japan  35.455592  139.572196  NaN

# %%
# Replace any missing (NaN) values in the 'Desc' column of the 'cities' dataframe
# with the string 'Yokohama, Kanagawa, Japan'

cities['Desc'] = cities['Desc'].fillna("Yokohama, Kanagawa, Japan")

# %%
# Print a summary of the 'cities' dataframe
cities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   City       100 non-null    object
#  1   City Code  100 non-null    int64
#  2   Region     100 non-null    object
#  3   Latitude   100 non-null    float64
#  4   Longitude  100 non-null    float64
#  5   Desc       100 non-null    object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 4.8+ KB

# %%
# Print a summary of the 'customers' dataframe
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 684 entries, 0 to 683
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Customer         684 non-null    object
#  1   Customer Number  684 non-null    int64
#  2   City Code        684 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 16.2+ KB

# %%
# Print a summary of the 'item_master' dataframe
item_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 827 entries, 0 to 826
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Item Number        827 non-null    int64
#  1   Product Group      827 non-null    object
#  2   Product Line       827 non-null    object
#  3   Product Sub Group  827 non-null    object
#  4   Product Type       827 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 32.4+ KB

# %%
# Print a summary of the 'sales_rep' dataframe
sales_rep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Manager          64 non-null     object
#  1   Manager Number   64 non-null     int64
#  2   Path             64 non-null     object
#  3   Sales Rep Name   64 non-null     object
#  4   Sales Rep Name1  64 non-null     object
#  5   Sales Rep Name2  59 non-null     object
#  6   Sales Rep Name3  39 non-null     object
#  7   Sales Rep ID     64 non-null     int64
# dtypes: int64(2), object(6)
# memory usage: 4.1+ KB

# %%
# Replace any missing (NaN) values in the 'sales_rep' dataframe with the string 'Unknown'
sales_rep = sales_rep.fillna('Unknown')

# Print a summary of the 'sales_rep' dataframe
sales_rep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Manager          64 non-null     object
#  1   Manager Number   64 non-null     int64
#  2   Path             64 non-null     object
#  3   Sales Rep Name   64 non-null     object
#  4   Sales Rep Name1  64 non-null     object
#  5   Sales Rep Name2  64 non-null     object
#  6   Sales Rep Name3  64 non-null     object
#  7   Sales Rep ID     64 non-null     int64
# dtypes: int64(2), object(6)
# memory usage: 4.1+ KB

# %%
# Print a summary of the 'sales' dataframe
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96466 entries, 0 to 96465
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   %KEY                    96466 non-null  int64
#  1   Cost                    96466 non-null  float64
#  2   Customer Number         96466 non-null  int64
#  3   Date                    96466 non-null  object
#  4   GrossSales              96466 non-null  float64
#  5   Invoice Date            96466 non-null  object
#  6   Invoice Number          96466 non-null  int64
#  7   Item Desc               96466 non-null  object
#  8   Item Number             96466 non-null  int64
#  9   Margin                  96466 non-null  float64
#  10  Order Number            96466 non-null  int64
#  11  Promised Delivery Date  96466 non-null  object
#  12  Sales                   96466 non-null  float64
#  13  Sales Qty               96466 non-null  float64
# ...

# %%
# Generate descriptive statistics for the 'cities' dataframe
cities.describe()
# Out:
#         City Code    Latitude   Longitude
# count  100.000000  100.000000  100.000000
# mean    50.500000   44.813257  -28.028824
# std     29.011492    9.437991   67.404008
# min      1.000000   25.774266 -122.674195
# 25%     25.750000   36.589686  -87.698940
# 50%     50.500000   42.354573   -3.188403
# 75%     75.250000   53.386865    7.764462
# max    100.000000   64.145981  141.354460

# %%
# Generate descriptive statistics for the 'customers' dataframe
customers.describe()
# Out:
#        Customer Number   City Code
# count     6.840000e+02  684.000000
# mean      1.001662e+07   49.833333
# std       7.898470e+03   30.390504
# min       1.000000e+07    1.000000
# 25%       1.001091e+07   23.000000
# 50%       1.001917e+07   48.000000
# 75%       1.002351e+07   74.000000
# max       1.002763e+07  100.000000

# %%
# Generate descriptive statistics for the 'item_master' dataframe
item_master.describe()
# Out:
#         Item Number
# count    827.000000
# mean   10522.220073
# std      310.710951
# min    10001.000000
# 25%    10268.500000
# 50%    10534.000000
# 75%    10800.500000
# max    11971.000000

# %%
# Generate descriptive statistics for the 'sales_rep' dataframe
sales_rep.describe()
# Out:
#        Manager Number  Sales Rep ID
# count       64.000000     64.000000
# mean       144.984375    143.515625
# std         27.551679     25.038378
# min        104.000000    103.000000
# 25%        118.000000    119.750000
# 50%        144.500000    144.500000
# 75%        169.000000    163.750000
# max        185.000000    185.000000

# %%
# Generate descriptive statistics for the 'sales' dataframe
sales.describe()
# Out:
#                 %KEY           Cost  Customer Number     GrossSales  \
# count   96466.000000   96466.000000     9.646600e+04   96466.000000
# mean    54715.166732     638.272186     1.001751e+07    1097.916246
# std     32130.384196    6435.093413     7.360265e+03   10243.399673
# min         1.000000   -9392.930000     1.000000e+07  -27929.875200
# 25%     26793.250000      13.280000     1.001242e+07      33.241525
# 50%     54144.500000      55.460000     1.001942e+07     114.010000
# 75%     82704.750000     180.540000     1.002352e+07     328.581400
# max    110409.000000  366576.000000     1.002758e+07  539200.000000
#
#        Invoice Number   Item Number         Margin   Order Number  \
# count    96466.000000  96466.000000   96466.000000   96466.000000
# mean    213089.625339  10512.149856     448.377554  193854.617637
# std      90626.900031    292.454663    3848.809989   73985.562829
# min     100001.000000  10001.000000  -27929.880000  100012.000000
# ...

# %%
# Display the first 5 rows of the 'cities' dataframe
cities.head()
# Out:
#            City  City Code Region   Latitude   Longitude  \
# 0      New York          1    USA  40.730599  -73.986581
# 1   Los Angeles          2    USA  34.053678 -118.242702
# 2       Chicago          3    USA  41.875555  -87.624421
# 3       Houston          4    USA  29.981501  -95.538360
# 4  Philadelphia          5    USA  39.952335  -75.163789
#
#                                           Desc
# 0                      "New York City, NY, US"
# 1    "Los Angeles, Los Angeles County, CA, US"
# 2               "Chicago, Cook County, IL, US"
# 3             "Houston, Harris County, TX, US"
# 4  "Philadelphia, Philadelphia County, PA, US"

# %%
# Display the first 5 rows of the 'customers' dataframe
customers.head()
# Out:
#             Customer  Customer Number  City Code
# 0  A Superior System         10000453          1
# 1                A&B         10000456         76
# 2                A&G         10000457          2
# 3       A&R Partners         10000458         43
# 4  A1 Datacom Supply         10000461         77

# %%
# Display the first 5 rows of the 'item_master' dataframe
item_master.head()
# Out:
#    Item Number Product Group Product Line Product Sub Group  \
# 0        10001     Beverages        Drink             Juice
# 1        10002     Beverages        Drink   Flavored Drinks
# 2        10003     Beverages        Drink   Flavored Drinks
# 3        10004     Beverages        Drink              Soda
# 4        10005     Beverages        Drink              Soda
#
#            Product Type
# 0  Pure Juice Beverages
# 1                Drinks
# 2                Drinks
# 3  Carbonated Beverages
# 4  Carbonated Beverages

# %%
# Display the first 5 rows of the 'sales_rep' dataframe

sales_rep.head()
# Out:
#          Manager  Manager Number                          Path  \
# 0   Amanda Honda             104     Amanda Honda-Amalia Craig
# 1   Amanda Honda             104       Amanda Honda-Cart Lynch
# 2   Amanda Honda             104   Amanda Honda-Molly McKenzie
# 3   Amanda Honda             104      Amanda Honda-Sheila Hein
# 4  Brenda Gibson             109  Brenda Gibson-Dennis Johnson
#
#    Sales Rep Name Sales Rep Name1 Sales Rep Name2 Sales Rep Name3  \
# 0    Amalia Craig    Amanda Honda    Amalia Craig         Unknown
# 1      Cart Lynch    Amanda Honda      Cart Lynch         Unknown
# 2  Molly McKenzie    Amanda Honda  Molly McKenzie         Unknown
# 3     Sheila Hein    Amanda Honda     Sheila Hein         Unknown
# 4  Dennis Johnson   Brenda Gibson  Dennis Johnson         Unknown
#
#    Sales Rep ID
# 0           103
# 1           112
# 2           159
# 3           176
# 4           121

# %%
# Display the first 5 rows of the 'sales' dataframe
sales.head()
# Out:
#    %KEY    Cost  Customer Number       Date  GrossSales Invoice Date  \
# 0  3428 -513.15         10012226  1/12/2012   -573.3835    1/12/2012
# 1  3429 -105.93         10012226  1/12/2012   -204.6638    1/12/2012
# 2  3430  -88.07         10012226  1/12/2012   -165.8016    1/12/2012
# 3  3431  -43.12         10012226  1/12/2012   -118.3703    1/12/2012
# 4  3432  -37.98         10012226  1/12/2012   -102.3319    1/12/2012
#
#    Invoice Number                   Item Desc  Item Number  Margin  \
# 0          318960     Cutting Edge Sliced Ham        10696  -37.29
# 1          318960  Washington Cranberry Juice        10009  -90.54
# 2          318960             Moms Sliced Ham        10385  -71.10
# 3          318960                 Tip Top Lox        10215  -70.52
# 4          318960        Just Right Beef Soup        10965  -60.26
#
#    Order Number Promised Delivery Date   Sales  Sales Qty  Sales Rep Number
# ...

# %%
# find common columns between the dataframes
set(item_master.columns).intersection(set(sales.columns))
# Out:
# {'Item Number'}

# %%
# Merge the 'sales' and 'item_master' dataframes using a left join on the 'Item Number' column
# and assign the resulting dataframe to a new variable called 'sales_item_master'

sales_item_master = pd.merge(sales, item_master, how='left', left_on='Item Number', right_on='Item Number')

# Display the first 5 rows of the 'sales_item_master' dataframe
sales_item_master.head()
# Out:
#    %KEY    Cost  Customer Number       Date  GrossSales Invoice Date  \
# 0  3428 -513.15         10012226  1/12/2012   -573.3835    1/12/2012
# 1  3429 -105.93         10012226  1/12/2012   -204.6638    1/12/2012
# 2  3430  -88.07         10012226  1/12/2012   -165.8016    1/12/2012
# 3  3431  -43.12         10012226  1/12/2012   -118.3703    1/12/2012
# 4  3432  -37.98         10012226  1/12/2012   -102.3319    1/12/2012
#
#    Invoice Number                   Item Desc  Item Number  Margin  \
# 0          318960     Cutting Edge Sliced Ham        10696  -37.29
# 1          318960  Washington Cranberry Juice        10009  -90.54
# 2          318960             Moms Sliced Ham        10385  -71.10
# 3          318960                 Tip Top Lox        10215  -70.52
# 4          318960        Just Right Beef Soup        10965  -60.26
#
#    Order Number Promised Delivery Date   Sales  Sales Qty  Sales Rep Number  \
# ...

# %%
# find common columns between the dataframes
set(customers.columns).intersection(set(sales.columns))
# Out:
# {'Customer Number'}

# %%
# Merge the 'sales' and 'customers' dataframes using a left join on the 'Customer Number' column
# and assign the resulting dataframe to a new variable called 'sales_customers'

sales_customers = pd.merge(sales, customers, how='left', left_on='Customer Number', right_on='Customer Number')

# Display the first 5 rows of the 'sales_customers' dataframe
sales_customers.head()
# Out:
#    %KEY    Cost  Customer Number       Date  GrossSales Invoice Date  \
# 0  3428 -513.15         10012226  1/12/2012   -573.3835    1/12/2012
# 1  3429 -105.93         10012226  1/12/2012   -204.6638    1/12/2012
# 2  3430  -88.07         10012226  1/12/2012   -165.8016    1/12/2012
# 3  3431  -43.12         10012226  1/12/2012   -118.3703    1/12/2012
# 4  3432  -37.98         10012226  1/12/2012   -102.3319    1/12/2012
#
#    Invoice Number                   Item Desc  Item Number  Margin  \
# 0          318960     Cutting Edge Sliced Ham        10696  -37.29
# 1          318960  Washington Cranberry Juice        10009  -90.54
# 2          318960             Moms Sliced Ham        10385  -71.10
# 3          318960                 Tip Top Lox        10215  -70.52
# 4          318960        Just Right Beef Soup        10965  -60.26
#
#    Order Number Promised Delivery Date   Sales  Sales Qty  Sales Rep Number  \
# ...

# %%
# find common columns between the dataframes
set(cities.columns).intersection(set(customers.columns))
# Out:
# {'City Code'}

# %%
# Merge the 'customers' and 'cities' dataframes using a left join on the 'City Code' column
# and assign the resulting dataframe to a new variable called 'customers_cities'
customers_cities = pd.merge(customers, cities, how='left', left_on='City Code', right_on='City Code')

# Display the first 5 rows of the 'customers_cities' dataframe
customers_cities.head()
# Out:
#             Customer  Customer Number  City Code         City Region  \
# 0  A Superior System         10000453          1     New York    USA
# 1                A&B         10000456         76    Barcelona  Spain
# 2                A&G         10000457          2  Los Angeles    USA
# 3       A&R Partners         10000458         43   Birmingham     UK
# 4  A1 Datacom Supply         10000461         77     Valencia  Spain
#
#     Latitude   Longitude                                               Desc
# 0  40.730599  -73.986581                            "New York City, NY, US"
# 1  41.382560    2.177135             "Barcelona, Barcelons, Catalonia, ES"
# 2  34.053678 -118.242702          "Los Angeles, Los Angeles County, CA, US"
# 3  52.481368   -1.898073            "Birmingham, Warwickshire, England, GB"
# 4  39.334197   -0.796958  "Provincia de Valencia / Valncia, Valencian C...

# %%
# find common columns between the dataframes
set(customers_cities.columns).intersection(set(sales_customers.columns))
# Out:
# {'City Code', 'Customer', 'Customer Number'}

# %%
# Merge the 'sales_customers' and 'customers_cities' dataframes using a left join on the 'Customer Number' column
# and assign the resulting dataframe to a new variable called 'sales_customers_cities'
sales_customers_cities = pd.merge(sales_customers, customers_cities, how='left', left_on=['City Code', 'Customer', 'Customer Number'], right_on=['City Code', 'Customer', 'Customer Number'])
sales_customers_cities.head()
# Out:
#    %KEY    Cost  Customer Number       Date  GrossSales Invoice Date  \
# 0  3428 -513.15         10012226  1/12/2012   -573.3835    1/12/2012
# 1  3429 -105.93         10012226  1/12/2012   -204.6638    1/12/2012
# 2  3430  -88.07         10012226  1/12/2012   -165.8016    1/12/2012
# 3  3431  -43.12         10012226  1/12/2012   -118.3703    1/12/2012
# 4  3432  -37.98         10012226  1/12/2012   -102.3319    1/12/2012
#
#    Invoice Number                   Item Desc  Item Number  Margin  ...  \
# 0          318960     Cutting Edge Sliced Ham        10696  -37.29  ...
# 1          318960  Washington Cranberry Juice        10009  -90.54  ...
# 2          318960             Moms Sliced Ham        10385  -71.10  ...
# 3          318960                 Tip Top Lox        10215  -70.52  ...
# 4          318960        Just Right Beef Soup        10965  -60.26  ...
#
#    Sales Qty Sales Rep Number  Customer  City Code  Profit Margin       City  \
# ...

# %%
# Display the first 5 rows of the 'sales_item_master' dataframe
sales_item_master.head()
# Out:
#    %KEY    Cost  Customer Number       Date  GrossSales Invoice Date  \
# 0  3428 -513.15         10012226  1/12/2012   -573.3835    1/12/2012
# 1  3429 -105.93         10012226  1/12/2012   -204.6638    1/12/2012
# 2  3430  -88.07         10012226  1/12/2012   -165.8016    1/12/2012
# 3  3431  -43.12         10012226  1/12/2012   -118.3703    1/12/2012
# 4  3432  -37.98         10012226  1/12/2012   -102.3319    1/12/2012
#
#    Invoice Number                   Item Desc  Item Number  Margin  \
# 0          318960     Cutting Edge Sliced Ham        10696  -37.29
# 1          318960  Washington Cranberry Juice        10009  -90.54
# 2          318960             Moms Sliced Ham        10385  -71.10
# 3          318960                 Tip Top Lox        10215  -70.52
# 4          318960        Just Right Beef Soup        10965  -60.26
#
#    Order Number Promised Delivery Date   Sales  Sales Qty  Sales Rep Number  \
# ...

# %%
#identify which Product Line have the highest total sales

#Group the sales_item_master data by product line 
#and calculate count, mean, min, max, and sum for the 'Sales' column
sales_item_master.groupby('Product Line')['Sales'].agg(['count', 'mean', 'min', 'max', 'sum']).sort_values('sum', ascending = False)
# Out:
#               count         mean       min        max          sum
# Product Line
# Food          86728  1098.491104 -17883.07  555376.00  95269936.47
# Drink          9738   984.056104 -27929.88  140991.25   9582738.34

# %%
#Total Sales by Product Line plot


#Group the sales_item_master data by product line 
#and calculate sum for the 'Sales' column
sales_item_master.groupby('Product Line')['Sales'].sum().sort_values(ascending = False).plot(kind= 'bar')

#add title to the plot
plt.title('Total Sales by Product Line')
# Out:
# <AxesSubplot:xlabel='Product Line'>

# %%
#Group the sales_item_master data by Product Group 
#and calculate count, mean, min, max, and sum for the 'Sales' column

#identify which Product Group have the highest total sales

sales_item_master.groupby('Product Group')['Sales'].agg(['count', 'mean', 'min', 'max', 'sum']).sort_values('sum', ascending = False)
# Out:
#                      count         mean       min        max          sum
# Product Group
# Produce              17376  1390.165504 -10890.44  555376.00  24155515.79
# Canned Products      10898  1882.919227  -6028.65  258946.70  20520053.74
# Deli                  8279  1767.697636 -17883.07   94260.45  14634768.73
# Frozen Foods         12611   752.198370  -5000.00   63307.92   9485973.64
# Snacks               14317   602.558510 -13749.60  287431.80   8626830.19
# Dairy                 8048   892.154195 -13778.70   80611.92   7180056.96
# Baking Goods          7835   859.243313  -1687.91  162869.27   6732171.36
# Beverages             5110  1237.406953 -27929.88  140991.25   6323149.53
# Starchy Foods         2662  1290.724715  -3418.90   52469.65   3435909.19
# Alcoholic Beverages   2774   821.207523 -11903.00  119030.00   2278029.67
# Breakfast Foods       1406   482.397667   -306.52  162139.72    678251.12
# ...

# %%
#Total Sales by Product Group plot

# Calculate sales metrics for each product group
sales_metrics = sales_item_master.groupby('Product Group')['Sales'].sum().sort_values(ascending = False)

# Create a bar plot to display total sales for each product group
sales_metrics.plot(kind='barh')

# Add a title to the plot
plt.title('Total Sales by Product Group')
# Out:
# Text(0.5, 1.0, 'Total Sales by Product Group')

# %%
sales.head()
item_master.head()
# Out:
#    Item Number Product Group Product Line Product Sub Group  \
# 0        10001     Beverages        Drink             Juice
# 1        10002     Beverages        Drink   Flavored Drinks
# 2        10003     Beverages        Drink   Flavored Drinks
# 3        10004     Beverages        Drink              Soda
# 4        10005     Beverages        Drink              Soda
#
#            Product Type
# 0  Pure Juice Beverages
# 1                Drinks
# 2                Drinks
# 3  Carbonated Beverages
# 4  Carbonated Beverages

# %%
#Group the sales_item_master data by Item Number
#and calculate count, mean, min, max, and sum for the 'Sales' column

#identify which items have the highest total sales

sales_item_master.groupby(['Item Number', 'Item Desc'])['Sales'].agg(['count', 'mean', 'min', 'max', 'sum']).sort_values('sum', ascending = False)
# Out:
#                                           count          mean       min  \
# Item Number Item Desc
# 10343       Better Large Canned Shrimp      187  55438.659947   -203.32
# 10190       High Top Dried Mushrooms        142  64942.456479   -325.22
# 10064       Red Spade Pimento Loaf          142  22643.054366      4.36
# 10403       Big Time Frozen Cheese Pizza    564   5351.238191   -711.99
# 10598       Landslide White Sugar           112  25304.422857  -1072.52
# ...                                         ...           ...       ...
# 10200       High Top Fancy Plums             12   -391.192500  -5000.00
# 10655       Bravo Fancy Canned Anchovies     12   -409.686667  -6028.65
# 10259       Choice Mints                     29   -202.467586  -3169.04
# 10243       Best Choice Dried Apples         18   -763.851111 -13749.60
# 10413       Big Time Lime Popsicles          59   -303.109831  -1110.79
#
#                                                 max          sum
# ...

# %%
#Top 20 Total Sales by Item Number Plot 

#Group the sales_item_master data by Item Number
#and calculate sum for the 'Sales' column, Create a bar plot 
sales_item_master.groupby('Item Number')['Sales'].sum().sort_values(ascending = False).head(20).plot(kind='bar')

# Add a title to the plot
plt.title('Top 20 Total Sales by Item Number')
# Out:
# Text(0.5, 1.0, 'Top 20 Total Sales by Item Number')

# %%
# convert the 'Date' column to datetime format
sales_item_master['Date'] = pd.to_datetime(sales_item_master['Date'])

#extract year, month, and day from the 'Date' column in the sales_item_master 
sales_item_master['year'] = sales_item_master['Date'].dt.year
sales_item_master['month'] = sales_item_master['Date'].dt.month
sales_item_master['day'] = sales_item_master['Date'].dt.day


#Group the sales_item_master data by year
#and calculate count, mean, min, max, and sum for the 'Sales' column

#identify which year have the highest total sales
sales_item_master.groupby('year')['Sales'].agg(['count', 'mean', 'min', 'max', 'sum']).sort_values('sum', ascending = False)
# Out:
#       count         mean       min       max          sum
# year
# 2013  41817  1022.406930 -27929.88  539200.0  42753990.60
# 2012  36444  1102.329664 -16667.71  517632.0  40173302.28
# 2014  18205  1204.360447 -17883.07  555376.0  21925381.93

# %%
#Total Sales per Year plot
sales_item_master.groupby('year')['Sales'].sum().plot(kind='bar')

# Add a title to the chart
plt.title('Total Sales per Year')
# Out:
# Text(0.5, 1.0, 'Total Sales per Year')

# %%
#identify which month have the highest total sales
sales_item_master.groupby(['year', 'month'])['Sales'].agg(['count', 'mean', 'min', 'max', 'sum']).sort_values('sum', ascending = False)
# Out:
#             count         mean       min        max         sum
# year month
# 2013 1       3882  1178.269812 -10890.44  539200.00  4574043.41
#      3       3359  1270.036758  -9165.60  458320.00  4266053.47
# 2012 6       2863  1487.691114  -5985.87  517632.00  4259259.66
# 2013 6       3586  1147.639286  -6235.28  539200.00  4115434.48
# 2014 1       3324  1237.924531  -1687.91  555376.00  4114861.14
# 2013 9       3884  1052.293018 -27929.88  219978.99  4087106.08
# 2012 3       3330  1168.827285  -1162.72  241348.38  3892194.86
#      2       3056  1265.565448 -10454.82  439987.20  3867568.01
#      8       3225  1178.069476 -12842.28  289077.50  3799274.06
# 2013 8       3854   984.167569 -13377.38  458320.00  3792981.81
# 2014 3       2984  1269.863003 -17883.07  472069.60  3789271.20
# 2012 9       3409  1096.831291  -8798.98  211179.83  3739097.87
# 2014 6       2814  1316.974318  -4839.98  258946.70  3705965.73
# ...

# %%
#identify Sales trends over time

# group sales data by year and month, and plot as a bar chart
sales_item_master.groupby(['year', 'month'])['Sales'].agg('sum').unstack().plot(kind='bar')

# add title to the plot
plt.title('Monthly Sales Report (January 2012 - June 2014)')
# Out:
# Text(0.5, 1.0, 'Monthly Sales Report (January 2012 - June 2014)')

# %%
#identify which day have the highest total sales
sales_item_master.groupby(['year', 'month', 'day'])['Sales'].agg(['count', 'mean', 'min', 'max', 'sum']).sort_values('sum', ascending = False)
# Out:
#                 count         mean      min        max        sum
# year month day
# 2013 12    25     222  2873.027297  -277.14  184400.00  637812.06
# 2014 6     12     130  4735.991000     2.58  258946.70  615678.83
# 2013 6     17     164  3706.474146     1.15  539200.00  607861.76
#      12    2      259  2346.066564  -530.37  215680.00  607631.24
# 2014 5     6      126  4812.328016 -1896.05  555376.00  606353.33
# ...               ...          ...      ...        ...        ...
# 2013 6     29       2  2176.575000  1119.79    3233.36    4353.15
# 2014 6     1        4   471.977500    43.13    1634.11    1887.91
# 2013 6     8        4   458.227500    41.87    1586.51    1832.91
# 2012 6     18       4   439.900000    40.20    1523.05    1759.60
# 2013 6     21       1  -131.360000  -131.36    -131.36    -131.36
#
# [626 rows x 5 columns]

# %%
sales_customers.head()
# Out:
#    %KEY    Cost  Customer Number       Date  GrossSales Invoice Date  \
# 0  3428 -513.15         10012226  1/12/2012   -573.3835    1/12/2012
# 1  3429 -105.93         10012226  1/12/2012   -204.6638    1/12/2012
# 2  3430  -88.07         10012226  1/12/2012   -165.8016    1/12/2012
# 3  3431  -43.12         10012226  1/12/2012   -118.3703    1/12/2012
# 4  3432  -37.98         10012226  1/12/2012   -102.3319    1/12/2012
#
#    Invoice Number                   Item Desc  Item Number  Margin  \
# 0          318960     Cutting Edge Sliced Ham        10696  -37.29
# 1          318960  Washington Cranberry Juice        10009  -90.54
# 2          318960             Moms Sliced Ham        10385  -71.10
# 3          318960                 Tip Top Lox        10215  -70.52
# 4          318960        Just Right Beef Soup        10965  -60.26
#
#    Order Number Promised Delivery Date   Sales  Sales Qty  Sales Rep Number  \
# ...

# %%
#identify which Costomers have the highest total sales
sales_customers.groupby(['Customer Number', 'Customer'])['Sales'].agg(['count', 'mean', 'min', 'max', 'sum']).sort_values('sum', ascending = False)
# Out:
#                                       count           mean        min  \
# Customer Number Customer
# 10021485        Paracel                 162   35137.381667   -1072.52
# 10021300        PageWave                 40  140826.081750   49226.08
# 10009676        Deak-Perera Group.      141   36266.078369    -344.87
# 10025024        Talarian                116   39128.126983  -13778.70
# 10025737        Userland                  8  449692.800000  207052.80
# ...                                     ...            ...        ...
# 10007268        Cabco West                1      38.530000      38.53
# 10025808        Valley Scribe             3      11.170000      11.17
# 10025418        Ultra-Image               2      12.670000      12.67
# 10021111        P.C'S                     1      15.020000      15.02
# 10000455        Caribian Specialties     13    -314.570000   -2168.19
#
#                                             max         sum
# Customer Number Customer
# ...

# %%
#Top 20 Customers by Sales

# Group data by customer and calculate the total sales for each customer
grouped_data = sales_customers.groupby(['Customer Number', 'Customer'])['Sales'].sum()

# Sort the results in descending order and select the top 20 customers
top_customers = grouped_data.sort_values(ascending=False).head(20)

# Create a bar plot of the top 20 customers by sales
top_customers.plot(kind='barh', title='Top 20 Customers by Sales')
# Out:
# <AxesSubplot:title={'center':'Top 20 Customers by Sales'}, ylabel='Customer Number,Customer'>

# %%
sales_customers_cities.columns
# Out:
# Index(['%KEY', 'Cost', 'Customer Number', 'Date', 'GrossSales', 'Invoice Date',
#        'Invoice Number', 'Item Desc', 'Item Number', 'Margin', 'Order Number',
#        'Promised Delivery Date', 'Sales', 'Sales Qty', 'Sales Rep Number',
#        'Customer', 'City Code', 'Profit Margin', 'City', 'Region', 'Latitude',
#        'Longitude', 'Desc'],
#       dtype='object')

# %%
#identify which Cities have the highest total sales

# This code groups sales data by city code and city name, and then calculates various statistics on the sales column.
# The resulting table is sorted by the total sales amount in descending order.
sales_customers_cities.groupby(['City Code', 'City'])['Sales'].agg(['count', 'mean', 'min', 'max', 'sum']).sort_values('sum', ascending = False)
# Out:
#                       count          mean       min        max         sum
# City Code City
# 53        Cardiff       738   8515.997846  -1687.91  184400.00  6284806.41
# 56        Leicester    1825   3385.090268  -1767.20  285350.40  6177789.74
# 20        Denver        979   6038.671389   -555.40  241348.38  5911859.29
# 23        Nashville     934   6043.320557 -13778.70  251404.56  5644461.40
# 30        Fresno        263  15917.681483   -512.24  279060.00  4186350.23
# ...                     ...           ...       ...        ...         ...
# 21        Washington    175    683.373657   -326.93   24820.00   119590.39
# 27        Milwaukee     334    251.614491   -517.65    8207.93    84039.24
# 17        Detroit       186    414.168065   -463.03    5053.26    77035.26
# 84        Berlin        149    500.051275  -2608.87    7066.75    74507.64
# 93        Hannover       97    316.290825   -167.55    3957.06    30680.21
#
# [99 rows x 5 columns]

# %%
#identify which Cities have the highest total sales

# This code groups sales data by city code and city name, and then calculates various statistics on the sales column.
# The resulting table is sorted by the total sales amount in descending order.
sales_customers_cities.groupby(['City Code', 'City'])['Sales'].sum().sort_values(ascending = False).head(20).plot(kind='bar')

# Add a title to the plot
plt.title('Top 20 Cities by Total Sales')
# Out:
# Text(0.5, 1.0, 'Top 20 Cities by Total Sales')

# %%
# Define the Profit_Margin_calculate function.
def Profit_Margin_calculate(Gross_Sales, Cost):
    if Gross_Sales == 0:
        Profit_Margin = 0
    else:
        # Subtract the cost from the gross sales and divide the result by gross sales to obtain the profit margin.
        Profit_Margin = (Gross_Sales - Cost) / Gross_Sales
    # Return the calculated profit margin.
    return Profit_Margin

# %%
# Apply the Profit_Margin_calculate function to each row of the DataFrame and store the results in a new column called "Profit Margin".
sales_customers['Profit Margin'] = sales_customers.apply(lambda row: Profit_Margin_calculate(row['GrossSales'], row['Cost']), axis=1)
sales_customers.head()
# Out:
#    %KEY    Cost  Customer Number       Date  GrossSales Invoice Date  \
# 0  3428 -513.15         10012226  1/12/2012   -573.3835    1/12/2012
# 1  3429 -105.93         10012226  1/12/2012   -204.6638    1/12/2012
# 2  3430  -88.07         10012226  1/12/2012   -165.8016    1/12/2012
# 3  3431  -43.12         10012226  1/12/2012   -118.3703    1/12/2012
# 4  3432  -37.98         10012226  1/12/2012   -102.3319    1/12/2012
#
#    Invoice Number                   Item Desc  Item Number  Margin  \
# 0          318960     Cutting Edge Sliced Ham        10696  -37.29
# 1          318960  Washington Cranberry Juice        10009  -90.54
# 2          318960             Moms Sliced Ham        10385  -71.10
# 3          318960                 Tip Top Lox        10215  -70.52
# 4          318960        Just Right Beef Soup        10965  -60.26
#
#    Order Number Promised Delivery Date   Sales  Sales Qty  Sales Rep Number  \
# ...

# %%
#which customers are the most profitable for the company

# Group the data by customer number and calculate the mean profit margin for each customer.
#and sort the data in descending order of mean profit margin.
sales_customers_sorted1 = sales_customers.groupby('Customer Number')['Profit Margin'].mean().sort_values(ascending = False)

#a left merge of two data frames based on the 'Customer Number' column, and the resulting data frame is sorted in descending order by the 'Profit Margin' column.
pd.merge(sales_customers_sorted1, customers, how='left', left_on='Customer Number', right_on='Customer Number').sort_values('Profit Margin', ascending = False)
# Out:
#      Customer Number  Profit Margin              Customer  City Code
# 0           10012023       1.000000                 FICOM         27
# 1           10017307       1.000000        Idyll Mountain         80
# 2           10021794       1.000000               PayMaxx         33
# 3           10010974       0.901754                   EDS         44
# 4           10025808       0.897766         Valley Scribe        100
# ..               ...            ...                   ...        ...
# 632         10024916       0.050240                 T & S         15
# 633         10025242      -0.207326             Teamsolve         31
# 634         10025418      -0.615677           Ultra-Image         38
# 635         10010832      -1.619788  Échange CAC Exchange          2
# 636         10009654      -1.680187     DCS International         65
#
# [637 rows x 4 columns]

# %%
#which items are the most profitable for the company to sell

# Group the data by Item Number and calculate the mean profit margin for each Item.
#and sort the data in descending order of mean profit margin.
sales_customers_sorted2 = sales_customers.groupby('Item Number')['Profit Margin'].mean().sort_values(ascending = False)

#a left merge of two data frames based on the 'Customer Number' column, and the resulting data frame is sorted in descending order by the 'Profit Margin' column.
pd.merge(sales_customers_sorted2, item_master, how='left', left_on='Item Number', right_on='Item Number').sort_values('Profit Margin', ascending = False)
# Out:
#      Item Number  Profit Margin        Product Group Product Line  \
# 0          10001       1.000000            Beverages        Drink
# 9          10262       1.000000        Starchy Foods         Food
# 16         10031       1.000000      Canned Products         Food
# 15         10666       1.000000                Dairy         Food
# 14         10647       1.000000      Canned Products         Food
# ..           ...            ...                  ...          ...
# 822        10610      -0.020555         Baking Goods         Food
# 823        10373      -0.076068                Dairy         Food
# 824        10269      -0.082019  Alcoholic Beverages        Drink
# 825        10537      -0.392971               Snacks         Food
# 826        10028      -0.674996      Canned Products         Food
#
#      Product Sub Group          Product Type
# 0                Juice  Pure Juice Beverages
# 9                Pasta         Starchy Foods
# ...

# %%
customers_cities.head()
# Out:
#             Customer  Customer Number  City Code         City Region  \
# 0  A Superior System         10000453          1     New York    USA
# 1                A&B         10000456         76    Barcelona  Spain
# 2                A&G         10000457          2  Los Angeles    USA
# 3       A&R Partners         10000458         43   Birmingham     UK
# 4  A1 Datacom Supply         10000461         77     Valencia  Spain
#
#     Latitude   Longitude                                               Desc
# 0  40.730599  -73.986581                            "New York City, NY, US"
# 1  41.382560    2.177135             "Barcelona, Barcelons, Catalonia, ES"
# 2  34.053678 -118.242702          "Los Angeles, Los Angeles County, CA, US"
# 3  52.481368   -1.898073            "Birmingham, Warwickshire, England, GB"
# 4  39.334197   -0.796958  "Provincia de Valencia / Valncia, Valencian C...

# %%
#Number of Customers by Region Plot

#the number of unique customers in each region, sorted from highest to lowest count.
customers_cities.groupby('Region')['Customer Number'].count().sort_values(ascending = False).plot(kind='bar')
#add title to the plot
plt.title('Number of Customers by Region')
# Out:
# Text(0.5, 1.0, 'Number of Customers by Region')

# %%
#the number of unique customers in each City, sorted from highest to lowest count.
customers_cities.groupby('City')['Customer Number'].count().sort_values(ascending = False)
# Out:
# City
# Yokohama     13
# Tokyo        13
# Sapporo      13
# Nagoya       13
# Osaka        13
#              ..
# Santander     4
# Cologne       4
# Leipzig       4
# Munich        4
# Zaragoza      4
# Name: Customer Number, Length: 99, dtype: int64

# %%
sales_customers_cities.head()
# Out:
#    %KEY    Cost  Customer Number       Date  GrossSales Invoice Date  \
# 0  3428 -513.15         10012226  1/12/2012   -573.3835    1/12/2012
# 1  3429 -105.93         10012226  1/12/2012   -204.6638    1/12/2012
# 2  3430  -88.07         10012226  1/12/2012   -165.8016    1/12/2012
# 3  3431  -43.12         10012226  1/12/2012   -118.3703    1/12/2012
# 4  3432  -37.98         10012226  1/12/2012   -102.3319    1/12/2012
#
#    Invoice Number                   Item Desc  Item Number  Margin  ...  \
# 0          318960     Cutting Edge Sliced Ham        10696  -37.29  ...
# 1          318960  Washington Cranberry Juice        10009  -90.54  ...
# 2          318960             Moms Sliced Ham        10385  -71.10  ...
# 3          318960                 Tip Top Lox        10215  -70.52  ...
# 4          318960        Just Right Beef Soup        10965  -60.26  ...
#
#    Customer_x City Code_x  Profit Margin  Customer_y  City Code_y       City  \
# ...

# %%
#the columns of sales_customers_cities data frame
sales_customers_cities.columns
# Out:
# Index(['%KEY', 'Cost', 'Customer Number', 'Date', 'GrossSales', 'Invoice Date',
#        'Invoice Number', 'Item Desc', 'Item Number', 'Margin', 'Order Number',
#        'Promised Delivery Date', 'Sales', 'Sales Qty', 'Sales Rep Number',
#        'Customer_x', 'City Code_x', 'Profit Margin', 'Customer_y',
#        'City Code_y', 'City', 'Region', 'Latitude', 'Longitude', 'Desc'],
#       dtype='object')

# %%
#in which cities the company has the most customers

#the number of unique customers in each city, sorted from highest to lowest count.
sales_customers_cities.groupby('City')['Customer Number'].count().sort_values(ascending = False)
# Out:
# City
# Sapporo         4483
# Tokyo           4476
# Bergen          3251
# Nagoya          3227
# Jacksonville    2944
#                 ...
# Albuquerque      178
# Washington       175
# Berlin           149
# Hannover          97
# Columbus          91
# Name: Customer Number, Length: 99, dtype: int64

# %%
#in which rigions the company has the most customers

#the number of unique customers in each city, sorted from highest to lowest count.
sales_customers_cities.groupby('Region')['Customer Number'].count().sort_values(ascending = False)
# Out:
# Region
# USA        26195
# UK         20257
# Japan      19624
# Nordic     18457
# Germany     8217
# Spain       5981
# Name: Customer Number, dtype: int64

# %%
#Number of Customers per Region plot

# Group by region and count the unique customer numbers, then sort in descending order
customers_per_region = sales_customers_cities.groupby('Region')['Customer Number'].nunique().sort_values(ascending=False)

# Create a bar plot
customers_per_region.plot(kind='bar')

# Add a title to the chart
plt.title('Number of Customers per Region')
# Out:
# Text(0.5, 1.0, 'Number of Customers per Region')

# %%
#in which cities the company has the most sales

#Group data by the 'City' column and calculate aggregate statistics on the 'Sales' column
#and Sort the results by the total sum of sales in each city in descending order
sales_customers_cities.groupby('City')['Sales'].agg(['count', 'mean', 'min', 'max', 'sum']).sort_values('sum', ascending = False)
# Out:
#             count          mean       min        max         sum
# City
# Cardiff       738   8515.997846  -1687.91  184400.00  6284806.41
# Leicester    1825   3385.090268  -1767.20  285350.40  6177789.74
# Denver        979   6038.671389   -555.40  241348.38  5911859.29
# Nashville     934   6043.320557 -13778.70  251404.56  5644461.40
# Fresno        263  15917.681483   -512.24  279060.00  4186350.23
# ...           ...           ...       ...        ...         ...
# Washington    175    683.373657   -326.93   24820.00   119590.39
# Milwaukee     334    251.614491   -517.65    8207.93    84039.24
# Detroit       186    414.168065   -463.03    5053.26    77035.26
# Berlin        149    500.051275  -2608.87    7066.75    74507.64
# Hannover       97    316.290825   -167.55    3957.06    30680.21
#
# [99 rows x 5 columns]

# %%
#in which rigions the company has the most sales

#Group data by the 'Region' column and calculate aggregate statistics on the 'Sales' column
#and Sort the results by the total sum of sales in each Region in descending order
sales_customers_cities.groupby('Region')['Sales'].agg(['count', 'mean', 'min', 'max', 'sum']).sort_values('sum', ascending = False)
# Out:
#          count         mean       min        max          sum
# Region
# USA      26195  1820.628860 -27929.88  555376.00  47691373.00
# UK       20257  1389.997642 -17362.20  310156.07  28157182.23
# Japan    19624   603.730892 -17883.07  129678.33  11847615.03
# Nordic   18457   608.331926 -16667.71  124491.20  11227982.36
# Spain     5981   576.760027  -3451.60  110213.10   3449601.72
# Germany   8217   404.519523  -2608.87   33491.27   3323936.92

# %%
#Total Sales by Region plot

#Group data by the 'Region' column and calculate aggregate statistics on the 'Sales' column
#and Sort the results by the total sum of sales in each Region in descending order
sales_customers_cities.groupby('Region')['Sales'].sum().sort_values(ascending = False).plot(kind='bar')

# Add a title to the chart
plt.title('Total Sales by Region')
# Out:
# Text(0.5, 1.0, 'Total Sales by Region')
